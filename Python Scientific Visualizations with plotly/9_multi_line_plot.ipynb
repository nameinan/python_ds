# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(10)
plt.plot(x,x**2)
plt.plot(x,x**3)
plt.plot(x,x*2)
plt.plot(x,2**x)

plt.show()

# %%
plt.plot(x,x**2,x,x**3,x,x*2,x,2**x)
plt.show()

# %%
x=np.array([[1,2,6],[4,5,3]])
plt.plot(x)
plt.show()

# %%
data=np.random.randn(2,10)
print(data)
plt.plot(data[0],data[1])
plt.show()
# Out:
# [[-0.77469708  0.68511314  0.79821374  0.5552735  -1.02016963  0.03657415
#   -0.01475191 -1.05745892  1.06466068  1.23651239]
#  [ 0.1240498  -0.61152393  0.6599282  -0.52588528  1.01235383  0.71107424
#    0.17579515 -0.93155799  1.46494441 -0.70993241]]
